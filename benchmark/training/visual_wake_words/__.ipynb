# %%
# !python train_vww.py
# Out:
# 2024-12-13 09:56:04.960609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734054964.977396  558138 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734054964.982507  558138 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-13 09:56:04.998969: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
ls -lt ./trained_models
# Out:
# total 4144
# -rw-r--r-- 1 kycho gpu-user 3024032 Dec 13 13:36 vww_96.h5
# -rw-r--r-- 1 kycho gpu-user  333288 Dec 11 12:05 vww_96_int8.tflite
# -rw-r--r-- 1 kycho gpu-user  866284 Dec 11 12:05 vww_96_float.tflite
# -rw-r--r-- 1 kycho gpu-user      53 Dec 11 12:05 vww_96_int8.md5
# -rw-r--r-- 1 kycho gpu-user      54 Dec 11 12:05 vww_96_float.md5
# drwxr-xr-x 2 kycho gpu-user    4096 Dec 11 12:05 vww/
# -rw-r--r-- 1 kycho gpu-user       0 Dec 11 12:05 README.md

# %%
# !python3 convert_vww.py trained_models/vww_96.h5
# Out:
# 2024-12-13 15:36:00.915766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734075360.931063  600133 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734075360.935753  600133 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-13 15:36:00.951208: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
ls -lt ./trained_models
# Out:
# total 4116
# -rw-r--r-- 1 kycho gpu-user  307752 Dec 13 15:36 vww_96_int8.tflite
# -rw-r--r-- 1 kycho gpu-user  864128 Dec 13 15:36 vww_96_float.tflite
# -rw-r--r-- 1 kycho gpu-user 3024032 Dec 13 13:36 vww_96.h5
# -rw-r--r-- 1 kycho gpu-user      53 Dec 11 12:05 vww_96_int8.md5
# -rw-r--r-- 1 kycho gpu-user      54 Dec 11 12:05 vww_96_float.md5
# drwxr-xr-x 2 kycho gpu-user    4096 Dec 11 12:05 vww/
# -rw-r--r-- 1 kycho gpu-user       0 Dec 11 12:05 README.md
