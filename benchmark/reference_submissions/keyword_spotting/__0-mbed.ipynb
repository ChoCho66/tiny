# %% [markdown]
# - conda create --prefix ./.MLPerf307-mbed python=3.7
# - conda install ipykernel
# - sudo apt-get update
# - sudo apt-get install mercurial
# - sudo apt install gcc-arm-none-eabi

# %%
# !pwd
# Out:
# /home/kycho/tiny/benchmark/reference_submissions/keyword_spotting

# %%
# !pip install mbed-cli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 22.5 MB/s eta 0:00:00
# ...

# %%
# !pip install jinja2 -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.10.3
#     Uninstalling Jinja2-2.10.3:
#       Successfully uninstalled Jinja2-2.10.3
# ...

# %%
# Deploy to the MCU Board
# 建立一個 mbed 項目
# !./setup_example.sh
# Out:
# --2024-12-11 17:10:19--  https://github.com/tensorflow/tensorflow/archive/v2.3.1.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/tensorflow/tensorflow/zip/refs/tags/v2.3.1 [following]
# --2024-12-11 17:10:19--  https://codeload.github.com/tensorflow/tensorflow/zip/refs/tags/v2.3.1
# Resolving codeload.github.com (codeload.github.com)... 20.27.177.114
# Connecting to codeload.github.com (codeload.github.com)|20.27.177.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘v2.3.1.zip’
#
# v2.3.1.zip              [    <=>             ]  58.92M  11.2MB/s    in 6.0s
#
# 2024-12-11 17:10:26 (9.79 MB/s) - ‘v2.3.1.zip’ saved [61778799]
#
# Archive:  v2.3.1.zip
# fcc4b966f1265f466e82617020af93670141b009
#    creating: tensorflow-2.3.1/
# ...

# %%
# 生成 Image: ./BUILD/NUCLEO_L4R5ZI/GCC_ARM/keyword_spotting.bin
# !mbed compile -m NUCLEO_L4R5ZI -t GCC_ARM
# Out:
# [mbed] Working path "/home/kycho/tiny/benchmark/reference_submissions/keyword_spotting" (library)
# [mbed] Program path "/home/kycho/tiny/benchmark/reference_submissions/keyword_spotting"
# [Warning] @,: Compiler version mismatch: Have 10.3.1; expected version >= 9.0.0 and < 10.0.0
# Building project keyword_spotting (NUCLEO_L4R5ZI, GCC_ARM)
# Scan: keyword_spotting
# Compile [  0.3%]: kws_model_settings.cc
# Compile [  0.5%]: mbed_tz_context.c
# Compile [  0.8%]: main.cpp
# Compile [  1.1%]: internally_implemented.cpp
# Compile [  1.3%]: kws_model_data.cc
# Compile [  1.6%]: AnalogOut.cpp
# Compile [  1.9%]: DigitalIn.cpp
# Compile [  2.1%]: BusIn.cpp
# Compile [  2.4%]: BusOut.cpp
# Compile [  2.7%]: DigitalInOut.cpp
# Compile [  2.9%]: BusInOut.cpp
# Compile [  3.2%]: DigitalOut.cpp
# Compile [  3.5%]: CAN.cpp
# Compile [  3.8%]: AnalogIn.cpp
# Compile [  4.0%]: BufferedSerial.cpp
# Compile [  4.3%]: I2CSlave.cpp
# Compile [  4.6%]: kws_input_data.cc
# ...
